# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
d = np.loadtxt("measure.txt")
# w = np.loadtxt("measure_1_white.txt")

# m = np.median(d)+0.6
# print(m)
d.shape

fig = plt.figure()
ax = fig.subplots(1, 1)
img = ax.imshow(d)
ax.contour(d, 5, colors='k')
plt.colorbar(img, ax=ax)
plt.show()

# %%
w = np.loadtxt("measure_05_white.txt")[:, 0:70]

w_mean = np.average(w, axis=0)-4

f = plt.figure(figsize=(5,4))
gs = gridspec.GridSpec(2,1,figure=fig)
ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])

ax1.imshow(w, aspect='auto')
ax2.plot(w_mean)
ax2.set_xlim([0, 70])
plt.show()
